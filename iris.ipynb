# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import adaline
from matplotlib.colors import ListedColormap

# %%
s = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

df = pd.read_csv(s, header=None, encoding='utf-8')

# %%
# Get the first 100 rows and four coluns
y = df.iloc[0:100, 4].values
# Filter
y = np.where(y=='Iris-setosa', 0 , 1)

# %%
X = df.iloc[0:100, [0,2]].values

# %%
# PLot values
plt.scatter(X[:50, 0], X[:50, 1], color='red', marker='o', label='Setosa')
plt.scatter(X[50:100, 0], X[50:100, 1], color='blue', marker='s', label='Veriscolor')
plt.xlabel('Sepal length [cm]')
plt.ylabel('Petal length [cm]')
plt.legend(loc='upper left')
plt.show()

# %%
ada = adaline.Adaline(X, y)

ada.fit(300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7632\2480153840.py in <module>
#       1 ada = adaline.Adaline(X, y)
#       2
# ----> 3 ada.fit(300)
#
# c:\Users\user\Desktop\Mohamad Folder\ml\adaline\adaline.py in fit(self, epochs)
#      32             errors = self.y - output
#      33
# ---> 34             change_w = self.eta * ((errors * self.X) / len(self.X))
#      35             change_b = self.eta * errors.mean()
#      36
#
# ValueError: operands could not be broadcast together with shapes (100,) (100,2)

# %%
plt.plot(ada.losses)
print(ada.losses)
# Out:
# [0.562919059588483, 0.5505869226747581, 0.5386142925299506, 0.5269906888035913, 0.5157059366686535, 0.5047501579149266, 0.49411376230203624, 0.48378743916453876, 0.47376214926174626, 0.4640291168651449, 0.45457982207648234, 0.4454059933697964, 0.43649960035086016, 0.4278528467277036, 0.41945816348605774, 0.411308202263751, 0.4033958289182521, 0.3957141172817346, 0.38825634309819224, 0.38101597813730137, 0.37398668447987404, 0.3671623089699048, 0.3605368778283475, 0.35410459142391476, 0.34785981919631853, 0.34179709472750697, 0.3359111109565865, 0.3301967155342377, 0.3246489063125596, 0.31926282696639385, 0.31403376274229655, 0.3089571363314363, 0.30402850386280506, 0.2992435510132356, 0.2945980892308189, 0.29008805206841864, 0.28570949162406767, 0.281458575085138, 0.2773315813732531, 0.2733248978870073, 0.2694350173396433, 0.2656585346889166, 0.26199214415646066, 0.2584326363340438, 0.2549768953741851, 0.25162189626266845, 0.2483647021705691, 0.2452024618834736, 0.24213240730564403, 0.2391518510369396, 0.23625818402037635, 0.23344887325826666, 0.23072145959493529, 0.22807355556407619, 0.22550284329886133, 0.22300707250297577, 0.22058405848079982, 0.21823168022501618, 0.21594787855996656, 0.21373065433913394, 0.2115780666951716, 0.20948823134094674, 0.2074593189201132, 0.20548955340576755, 0.20357721054578753, 0.201720616353493, 0.19991814564230573, 0.1981682206031282, 0.19646